# %% [markdown]
# <a href="https://colab.research.google.com/github/ujjwalbasnyat/data_visualization_synth_employee_dataset/blob/main/68340c1d2869c01b701567f1DataVizualization_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Data Visualization and Presentation - AI Fellowship
#
# ### Exploring Employee Dataset with Data Visualizations
#
# In this assignment, you will work with a synthetic employee dataset that captures various demographic, educational, and professional attributes such as age, experience, education level, job role, salary, performance scores, and more.
#
# The goal of this assignment is to practice and apply univariate and bivariate data visualization techniques using libraries like Matplotlib and Seaborn. You will create and interpret a variety of plot types to uncover trends, distributions, and relationships within the data.
#
# **Learning Objectives:**
#
# - Understand how to choose the appropriate plot for different types of data
#
# - Gain insights from visual patterns and anomalies
#
# - Practice customization and annotation to make plots more informative
#
# - Interpret visualizations in a real-world context (e.g., HR analytics)

# %%
# !pip install PlotChecker
# Out:
# Requirement already satisfied: PlotChecker in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: matplotlib>=2 in /usr/local/lib/python3.11/dist-packages (from PlotChecker) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from PlotChecker) (2.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from PlotChecker) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2->PlotChecker) (2.9.0.post0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotchecker import PlotChecker

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/AayushFuse/data/refs/heads/main/emp_info.csv")
df.head()
# Out:
#    Age  Experience  Salary  Performance_Score  Work_Life_Balance   Department  \
# 0   38          16   51565                  1                  4           HR
# 1   34           8   68154                  2                  5           HR
# 2   39          17   53322                  3                  3  Engineering
# 3   45          23   56194                  4                  1           HR
# 4   33          10   34832                  3                  2           HR
#
#   Education_Level  Gender Marital_Status  Job_Role
# 0        Bachelor  Female        Married   Manager
# 1             PhD  Female         Single     Clerk
# 2     High School  Female        Married  Engineer
# 3        Bachelor    Male        Married   Manager
# 4        Bachelor    Male         Single     Clerk

# %% [markdown]
# ## Data Descriptions
#
# - **Age**: Age of the employee in years.
#
# - **Experience**: Number of years the employee has worked professionally.
#
# - **Salary**: Annual salary of the employee in USD.
#
# - **Performance_Score**: Employee’s performance rating on a scale from 1 (lowest) to 5 (highest).
#
# - **Work_Life_Balance**: Self-reported rating of work-life balance, from 1 (poor) to 5 (excellent).
#
# - **Department**: The department in which the employee works (e.g., Engineering, HR, Finance).
#
# - **Education_Level**: The highest level of education attained by the employee.
#
# - **Gender**: Gender identity of the employee.
#
# - **Marital_Status**: Current marital status of the employee (e.g., Single, Married).
#
# - **Job_Role**: The job title or role of the employee within the organization.

# %% [markdown]
# ### BASIC PLOTTING TASKS

# %%
### Ex-1-Task-1
fig, ax = plt.subplots(figsize=(8, 5))
# Plot a histogram to explore the distribution of salaries in the dataset.
# Keep the title of the plot "Salary Distribution"
### BEGIN SOLUTION
# YOUR CODE HERE
ax.set_title('Salary Distribution')
sns.despine(fig)
sns.histplot(data=df, x='Salary', ax=ax)
ax.set_xlabel('Salary')
ax.set_ylabel('Count')
# raise NotImplementedError()
### END SOLUTION
# Out:
# Text(0, 0.5, 'Count')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-1-Task-2
# Create a scatterplot to explore the relationship between Age and Salary.
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION
# YOUR CODE HERE
ax.set_title('Age vs Salary')
ax.scatter(x='Age', y='Salary', data=df)
ax.set_xlabel('Age')
ax.set_ylabel('Salary')
plt.show()
# raise NotImplementedError()
### END SOLUTION

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-1-Task-3
# Plot average salary per department using a line chart.
# Set Title: "Average Salary by Department"
# Use 'x' marker
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION
# YOUR CODE HERE
ax.set_title('Average Salary by Department')
avg = df.groupby('Department').agg({'Salary':'mean'})
avg_df = avg.reset_index()
sns.lineplot(data=avg_df, x='Salary', y='Department', marker='x', markeredgecolor='red', ax=ax)
plt.xlabel('Salary')
plt.ylabel('Department')
# raise NotImplementedError()
### END SOLUTION
# Out:
# Text(0, 0.5, 'Department')

# %%
# INTENTIONALLY LEFT BLANK

# %% [markdown]
# ### UNIVARIATE ANALYSIS TASKS

# %%
### Ex-2-Task-1
# Create a boxplot to visualize the distribution of Age.
# Set title: Boxplot of Age
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION
# YOUR CODE HERE
sns.boxplot(data=df, x='Age', color='yellow', ax=ax)
ax.set_title('Boxplot of Age')
ax.set_xlabel('Age')
# raise NotImplementedError()
### END SOLUTION
# Out:
# Text(0.5, 0, 'Age')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-2-Task-2
# Plot a bar chart showing the count of each education level.
# Set title: "Education Level Count"
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION
# YOUR CODE HERE
ax.set_title('Education Level Count')
ax.set_xlabel('Education Level')
ax.set_ylabel('Count')
sns.countplot(data=df, x='Education_Level', ax=ax)
# raise NotImplementedError()
### END SOLUTION
# Out:
# <Axes: title={'center': 'Education Level Count'}, xlabel='Education Level', ylabel='Count'>

# %%
# INTENTIONALLY LEFT BLANK

# %% [markdown]
# ### BIVARIATE ANALYSIS TASKS

# %%
### Ex-3-Task-1
# Create a scatterplot of Experience vs Salary, colored by Gender.
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION
# YOUR CODE HERE
sns.scatterplot(data=df, x='Experience', y='Salary', hue='Gender', ax=ax)
plt.xlabel('Experience')
plt.ylabel('Salary')
# raise NotImplementedError()
### END SOLUTION
# Out:
# Text(0, 0.5, 'Salary')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-3-Task-2
# Create a boxplot showing Salary distribution across Departments.
fig, ax = plt.subplots(figsize=(10, 6))
### BEGIN SOLUTION
# YOUR CODE HERE
sns.boxplot(data=df, x='Salary', y='Department', ax=ax)
ax.set_title('Boxplot of Salary distributon across Departments')
plt.xlabel('Salary')
plt.ylabel('Department')
# raise NotImplementedError()
### END SOLUTION
# Out:
# Text(0, 0.5, 'Department')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-3-Task-3
# Show correlation between numerical variables using a heatmap.
fig, ax = plt.subplots(figsize=(10, 6))
# Use seaborn heatmap
### BEGIN SOLUTION
# YOUR CODE HERE
corr = df.select_dtypes(include=['integer']).corr()
sns.heatmap(corr, annot=True)
# raise NotImplementedError()
### END SOLUTION
# Out:
# <Axes: >

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-4-Task-1
# Use seaborn (declarative) to plot count of each marital status.
fig, ax = plt.subplots(figsize=(10, 6))
### BEGIN SOLUTION
# YOUR CODE HERE
sns.countplot(data = df, x='Marital_Status', ax=ax)
ax.set_xlabel('Marital Status')
ax.set_ylabel('Count')
# raise NotImplementedError()
### END SOLUTION
# Out:
# Text(0, 0.5, 'Count')

# %%
# INTENTIONALLY LEFT BLANK
